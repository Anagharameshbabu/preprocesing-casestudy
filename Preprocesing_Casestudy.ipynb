# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder,StandardScaler,MinMaxScaler

# %%
data = pd.read_csv('/content/House_Pricing.csv')

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# ...

# %%
data.shape
# Out:
# (21613, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
data.isna().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
data['No of Bathrooms'].mode()
# Out:
# 0    2.5
# Name: No of Bathrooms, dtype: float64

# %%
data['Zipcode'].mode()
# Out:
# 0    98103.0
# Name: Zipcode, dtype: float64

# %%
data['Longitude'].mode()
# Out:
# 0   -122.29
# Name: Longitude, dtype: float64

# %%
data['Waterfront View'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['No of Times Visited'].unique()
# Out:
# array([nan, 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
data.drop(columns=['No of Times Visited'],inplace=True)
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View Condition of the House  Overall Grade  \
# 0              No                   Fair              7
# ...

# %%
sns.histplot(data['Sale Price'],kde=True)
# Out:
# <Axes: xlabel='Sale Price', ylabel='Count'>

# %%
sns.histplot(data['No of Bathrooms'],kde=True)
# Out:
# <Axes: xlabel='No of Bathrooms', ylabel='Count'>

# %%
sns.histplot(data['Flat Area (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Flat Area (in Sqft)', ylabel='Count'>

# %%
sns.histplot(data['Lot Area (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Lot Area (in Sqft)', ylabel='Count'>

# %%
sns.histplot(data['Area of the House from Basement (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Area of the House from Basement (in Sqft)', ylabel='Count'>

# %%
sns.histplot(data['Living Area after Renovation (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Living Area after Renovation (in Sqft)', ylabel='Count'>

# %%
data['Sale Price'].fillna(data['Sale Price'].mean(),inplace=True)
data['No of Bathrooms'].fillna(data['No of Bathrooms'].mode(),inplace=True)
data['Flat Area (in Sqft)'].fillna(data['Flat Area (in Sqft)'].mean(),inplace=True)
data['Lot Area (in Sqft)'].fillna(data['Lot Area (in Sqft)'].mean(),inplace=True)
data['Area of the House from Basement (in Sqft)'].fillna(data['Area of the House from Basement (in Sqft)'].mean(),inplace=True)
data['Zipcode'].fillna(data['Zipcode'].mode(),inplace=True)
data['Latitude'].fillna(data['Latitude'].mode(),inplace=True)
data['Longitude'].fillna(data['Longitude'].mode(),inplace=True)
data['Living Area after Renovation (in Sqft)'].fillna(data['Living Area after Renovation (in Sqft)'].mean(),inplace=True)
data.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %% [markdown]
# outliers

# %%
import matplotlib.pyplot as plt
outliers_columns=['Sale Price','No of Bedrooms','Flat Area (in Sqft)','Lot Area (in Sqft)','Area of the House from Basement (in Sqft)','Basement Area (in Sqft)','Living Area after Renovation (in Sqft)']
for i in outliers_columns:
  plt.figure()
  sns.boxplot(data[i])

# %%
Q1 = np.percentile(data['Sale Price'],25,interpolation='midpoint')
Q2 = np.percentile(data['Sale Price'],50,interpolation='midpoint')
Q3 = np.percentile(data['Sale Price'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 322000.0
# 450000.0
# 645000.0

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 323000.0

# %%
min_value = Q1-1.5*IQR
max_value = Q3+1.5*IQR
print(min_value)
print(max_value)
# Out:
# -162500.0
# 1129500.0

# %%
outliers = []
for x in data['Sale Price']:
  if((x>max_value) or (x<min_value)):
    outliers.append(x)
print(outliers)
# Out:
# [1230000.0, 2000000.0, 1350000.0, 1330000.0, 1450000.0, 2250000.0, 1510000.0, 2400000.0, 2900000.0, 1370000.0, 2050000.0, 3080000.0, 2380000.0, 1380000.0, 1400000.0, 1350000.0, 1550000.0, 1300000.0, 1450000.0, 1200000.0, 1150000.0, 1390000.0, 1280000.0, 1200000.0, 1490000.0, 2250000.0, 1600000.0, 2130000.0, 1450000.0, 1950000.0, 1220000.0, 3070000.0, 1250000.0, 1150000.0, 1480000.0, 1580000.0, 1300000.0, 1310000.0, 2250000.0, 1360000.0, 1220000.0, 2400000.0, 1270000.0, 1200000.0, 1320000.0, 2450000.0, 1240000.0, 1570000.0, 1130000.0, 1200000.0, 1280000.0, 1960000.0, 1750000.0, 5110000.0, 1150000.0, 1880000.0, 1230000.0, 2300000.0, 2260000.0, 5300000.0, 1200000.0, 2200000.0, 1130000.0, 1180000.0, 1700000.0, 1400000.0, 2540000.0, 1360000.0, 1230000.0, 5350000.0, 1330000.0, 1220000.0, 1250000.0, 1300000.0, 1180000.0, 1380000.0, 1150000.0, 1200000.0, 2250000.0, 1230000.0, 1270000.0, 1680000.0, 1930000.0, 1180000.0, 2350000.0, 1140000.0, 1320000.0, 1430000.0, 1530000.0, 1570000.0, 1130000
# ...

# %%
data['Sale Price'] = data['Sale Price'].clip(min_value,max_value)

# %%
Q1 = np.percentile(data['Flat Area (in Sqft)'],25,interpolation='midpoint')
Q2 = np.percentile(data['Flat Area (in Sqft)'],50,interpolation='midpoint')
Q3 = np.percentile(data['Flat Area (in Sqft)'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 1430.0
# 1910.0
# 2550.0

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 1120.0

# %%
min_value = Q1-1.5*IQR
max_value = Q3+1.5*IQR
print(min_value)
print(max_value)
# Out:
# -250.0
# 4230.0

# %%
outliers = []
for x in data['Flat Area (in Sqft)']:
  if((x>max_value) or (x<min_value)):
    outliers.append(x)
print(outliers)
# Out:
# [5420.0, 4770.0, 4380.0, 5180.0, 4410.0, 5050.0, 5310.0, 4550.0, 4290.0, 4290.0, 4800.0, 6070.0, 4870.0, 4860.0, 4860.0, 4410.0, 4760.0, 6050.0, 4740.0, 5403.0, 4380.0, 4640.0, 6050.0, 4370.0, 4570.0, 4670.0, 4860.0, 4270.0, 4890.0, 4390.0, 4250.0, 5670.0, 4475.0, 6070.0, 4300.0, 4390.0, 8010.0, 4460.0, 4610.0, 4380.0, 4250.0, 4930.0, 7390.0, 4640.0, 5320.0, 8000.0, 6563.0, 4740.0, 5450.0, 4440.0, 4830.0, 4280.0, 4570.0, 4370.0, 5710.0, 5620.0, 5774.0, 4470.0, 4490.0, 5040.0, 5770.0, 5180.0, 6400.0, 4490.0, 6055.0, 4250.0, 6300.0, 4350.0, 4460.0, 4340.0, 4250.0, 5110.0, 4700.0, 4910.0, 4750.0, 6840.0, 4930.0, 5180.0, 5130.0, 6640.0, 5740.0, 7350.0, 4510.0, 4300.0, 4870.0, 5020.0, 4740.0, 5370.0, 4860.0, 6930.0, 6550.0, 6110.0, 4883.0, 5010.0, 4660.0, 4600.0, 4910.0, 5410.0, 4270.0, 4520.0, 5340.0, 5230.0, 5370.0, 4730.0, 4430.0, 5780.0, 6240.0, 10040.0, 4250.0, 5360.0, 4610.0, 7480.0, 5620.0, 4340.0, 7080.0, 5760.0, 4400.0, 4280.0, 9200.0, 4320.0, 4420.0, 4380.0, 4580.0, 5310.0, 4660
# ...

# %%
data['Flat Area (in Sqft)'] = data['Flat Area (in Sqft)'].clip(min_value,max_value)

# %%
Q1 = np.percentile(data['Lot Area (in Sqft)'],25,interpolation='midpoint')
Q2 = np.percentile(data['Lot Area (in Sqft)'],50,interpolation='midpoint')
Q3 = np.percentile(data['Lot Area (in Sqft)'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 5040.0
# 7620.0
# 10701.0

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 5661.0

# %%
min_value = Q1-1.5*IQR
max_value = Q3+1.5*IQR
print(min_value)
print(max_value)
# Out:
# -3451.5
# 19192.5

# %%
outliers = []
for x in data['Lot Area (in Sqft)']:
  if((x>max_value) or (x<min_value)):
    outliers.append(x)
print(outliers)
# Out:
# [101930.0, 19901.0, 44867.0, 34848.0, 24186.0, 65005.0, 21235.0, 20158.0, 50094.0, 50529.0, 35102.0, 39683.0, 41800.0, 36847.0, 107593.0, 33919.0, 28037.0, 111078.0, 315374.0, 60984.0, 19850.0, 25245.0, 38332.0, 21000.0, 35003.0, 66211.0, 155073.0, 33474.0, 19436.0, 28040.0, 94300.0, 221284.0, 36224.0, 40510.0, 20100.0, 57346.0, 26300.0, 49375.0, 22111.0, 78408.0, 64904.0, 45004.0, 43995.0, 20000.0, 32633.0, 19800.0, 77972.0, 29970.0, 40438.0, 69415.0, 209959.0, 26977.0, 25600.0, 22357.0, 40139.0, 143947.0, 32239.0, 37461.0, 174240.0, 171626.0, 27260.0, 19700.0, 219978.0, 24920.0, 20978.0, 28025.0, 181319.0, 19635.0, 57063.0, 39150.0, 194278.0, 230652.0, 36947.0, 76230.0, 24069.0, 40518.0, 29242.0, 29170.0, 108900.0, 217014.0, 22370.0, 75794.0, 84942.0, 217800.0, 32666.0, 31465.0, 34293.0, 26326.0, 36400.0, 55867.0, 22267.0, 209523.0, 19252.0, 23488.0, 25958.0, 26055.0, 39478.0, 51836.0, 37769.0, 72745.0, 22594.0, 218252.0, 31400.0, 23680.0, 40419.0, 34133.0, 36276.0, 40097.0, 36085.
# ...

# %%
data['Lot Area (in Sqft)'] = data['Lot Area (in Sqft)'].clip(min_value,max_value)

# %%
Q1 = np.percentile(data['Area of the House from Basement (in Sqft)'],25,interpolation='midpoint')
Q2 = np.percentile(data['Area of the House from Basement (in Sqft)'],50,interpolation='midpoint')
Q3 = np.percentile(data['Area of the House from Basement (in Sqft)'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 1190.0
# 1560.0
# 2210.0

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 1020.0

# %%
min_value = Q1-1.5*IQR
max_value = Q3+1.5*IQR
print(min_value)
print(max_value)
# Out:
# -340.0
# 3740.0

# %%
outliers = []
for x in data['Area of the House from Basement (in Sqft)']:
  if((x>max_value) or (x<min_value)):
    outliers.append(x)
print(outliers)
# Out:
# [3890.0, 3760.0, 4750.0, 5310.0, 3840.0, 6070.0, 4040.0, 3840.0, 4860.0, 3860.0, 4410.0, 6050.0, 4740.0, 5403.0, 4120.0, 4150.0, 4370.0, 4570.0, 4670.0, 4230.0, 4270.0, 5670.0, 4475.0, 6070.0, 4300.0, 3990.0, 5990.0, 4460.0, 4190.0, 4250.0, 4930.0, 3840.0, 5000.0, 5320.0, 6720.0, 4210.0, 3890.0, 3830.0, 5153.0, 4210.0, 4740.0, 5450.0, 4280.0, 3880.0, 4570.0, 3750.0, 4130.0, 5710.0, 4700.0, 3810.0, 4490.0, 4150.0, 4070.0, 3840.0, 5770.0, 4030.0, 3810.0, 4490.0, 3840.0, 4360.0, 3960.0, 4460.0, 4340.0, 3850.0, 4750.0, 4350.0, 4160.0, 5180.0, 4070.0, 5130.0, 6350.0, 3770.0, 3780.0, 4750.0, 3950.0, 3915.0, 3880.0, 4870.0, 4030.0, 4740.0, 3850.0, 4860.0, 4310.0, 3930.0, 4070.0, 4080.0, 5400.0, 6110.0, 3859.0, 4600.0, 3940.0, 3800.0, 4230.0, 4070.0, 5050.0, 4000.0, 4220.0, 3860.0, 3890.0, 3890.0, 5230.0, 5370.0, 4140.0, 4270.0, 4430.0, 4210.0, 4130.0, 3780.0, 4610.0, 7680.0, 4250.0, 3820.0, 4120.0, 3770.0, 4610.0, 5080.0, 4140.0, 4340.0, 3770.0, 5760.0, 4390.0, 4000.0, 3810.0, 4400.0, 6200.
# ...

# %%
data['Area of the House from Basement (in Sqft)']= data['Area of the House from Basement (in Sqft)'].clip(min_value,max_value)

# %%
Q1 = np.percentile(data['Basement Area (in Sqft)'],25,interpolation='midpoint')
Q2 = np.percentile(data['Basement Area (in Sqft)'],50,interpolation='midpoint')
Q3 = np.percentile(data['Basement Area (in Sqft)'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 0.0
# 0.0
# 560.0

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 560.0

# %%
min_value = Q1-1.5*IQR
max_value = Q3+1.5*IQR
print(min_value)
print(max_value)
# Out:
# -840.0
# 1400.0

# %%
outliers = []
for x in data['Basement Area (in Sqft)']:
  if((x>max_value) or (x<min_value)):
    outliers.append(x)
print(outliers)
# Out:
# [1530, 1700, 1620, 1510, 1600, 1700, 1600, 1490, 1640, 1460, 2000, 1430, 1950, 2060, 1820, 1450, 1950, 1600, 1600, 1580, 1470, 1780, 1900, 1450, 1760, 1600, 1720, 1760, 1510, 1800, 1810, 1460, 1830, 1590, 1620, 1420, 1960, 1560, 2020, 2110, 1490, 2390, 1600, 1780, 2020, 1700, 1410, 1450, 1500, 1800, 1580, 1800, 1480, 1670, 1510, 1800, 1620, 2570, 2110, 1490, 2590, 1580, 1480, 1410, 1480, 2500, 1940, 1550, 2350, 2490, 1481, 1470, 1520, 1850, 1830, 1660, 2130, 2600, 1450, 1850, 1690, 1850, 1600, 1520, 1780, 2620, 1600, 1430, 1798, 2060, 1610, 1780, 1440, 1590, 1500, 1450, 1600, 1690, 1500, 1470, 1570, 1590, 1650, 1500, 1510, 1910, 1630, 2360, 1852, 2090, 2400, 1480, 1790, 2150, 1500, 1440, 1500, 1430, 1720, 1500, 1410, 1680, 2100, 3000, 1870, 1530, 1420, 1460, 1710, 1640, 1500, 1410, 2030, 1650, 1820, 1540, 1540, 1710, 1460, 2850, 1610, 1800, 1660, 1420, 1420, 2170, 1450, 2150, 1560, 1560, 1830, 1720, 1460, 1590, 1670, 1500, 1530, 1430, 1500, 1530, 2170, 1940, 2040, 1800, 1490, 1750, 1
# ...

# %%
data['Basement Area (in Sqft)'] = data['Basement Area (in Sqft)'].clip(min_value,max_value)

# %%
Q1 = np.percentile(data['Living Area after Renovation (in Sqft)'],25,interpolation='midpoint')
Q2 = np.percentile(data['Living Area after Renovation (in Sqft)'],50,interpolation='midpoint')
Q3 = np.percentile(data['Living Area after Renovation (in Sqft)'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 1490.0
# 1840.0
# 2360.0

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 870.0

# %%
min_value = Q1-1.5*IQR
max_value = Q3+1.5*IQR
print(min_value)
print(max_value)
# Out:
# 185.0
# 3665.0

# %%
outliers = []
for x in data['Living Area after Renovation (in Sqft)']:
  if((x>max_value) or (x<min_value)):
    outliers.append(x)
print(outliers)
# Out:
# [4760.0, 4110.0, 3740.0, 3836.0, 3890.0, 4180.0, 3920.0, 4550.0, 3860.0, 3860.0, 4050.0, 4680.0, 3930.0, 4300.0, 3850.0, 4210.0, 3980.0, 3920.0, 3715.0, 4190.0, 4230.0, 3890.0, 4100.0, 4090.0, 3680.0, 4100.0, 3720.0, 4750.0, 3950.0, 5790.0, 3890.0, 4320.0, 4640.0, 3970.0, 4600.0, 3950.0, 5600.0, 3820.0, 3950.0, 3720.0, 4800.0, 3990.0, 3720.0, 3860.0, 3900.0, 3720.0, 4060.0, 3910.0, 3730.0, 3760.0, 3910.0, 3770.0, 3960.0, 4620.0, 4050.0, 3860.0, 3730.0, 4470.0, 4890.0, 3690.0, 3680.0, 3780.0, 3980.0, 3690.0, 4240.0, 3890.0, 4670.0, 4050.0, 4350.0, 5380.0, 4330.0, 3830.0, 5000.0, 3680.0, 4250.0, 4080.0, 4110.0, 4190.0, 3770.0, 3736.0, 4600.0, 3980.0, 4170.0, 4090.0, 3750.0, 3680.0, 4630.0, 3910.0, 3880.0, 4110.0, 3960.0, 3710.0, 3930.0, 4170.0, 3721.0, 3930.0, 4650.0, 4020.0, 3920.0, 3900.0, 4470.0, 3680.0, 3710.0, 4240.0, 4020.0, 3920.0, 4320.0, 3770.0, 4190.0, 3720.0, 4230.0, 3960.0, 3950.0, 3740.0, 3740.0, 3670.0, 4080.0, 5340.0, 4440.0, 3690.0, 4690.0, 4920.0, 4160.0, 3810.0, 4480.
# ...

# %%
data['Living Area after Renovation (in Sqft)'] = data['Living Area after Renovation (in Sqft)'].clip(min_value,max_value)

# %% [markdown]
# Encoding

# %%
categorical_columns = ['Waterfront View','Condition of the House']

# %%
data_encoded = pd.get_dummies(data,columns=categorical_columns,dtype=int,drop_first=True)
data_encoded.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  Zipcode  \
# ...

# %%
data_encoded.shape
# Out:
# (21613, 23)

# %%
numerical_columns = ['Sale Price','Flat Area (in Sqft)','Lot Area (in Sqft)','Area of the House from Basement (in Sqft)','Basement Area (in Sqft)','Living Area after Renovation (in Sqft)','Lot Area after Renovation (in Sqft)']

# %%
data_std_scaled= data_encoded.copy()

std_scaler = StandardScaler()
data_std_scaled[numerical_columns]= std_scaler.fit_transform(data_std_scaled[numerical_columns])
data_std_scaled.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017   -1.158771               3
# 1  6414100192    14 December 2017    0.105511               3
# 2  5631500400    15 February 2016   -1.326355               2
# 3  2487200875    14 December 2017    0.369486               4
# 4  1954400510    15 February 2016   -0.006479               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00            -1.046695           -0.605698           1.0
# 1             2.25             0.610390           -0.290710           2.0
# 2             1.00            -1.535476            0.254978           1.0
# 3             3.00            -0.116820           -0.734305           1.0
# 4             2.00            -0.450622           -0.124907           1.0
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  Zipcode  \
# ...

# %%
data_std_scaled.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.161300e+04    21613.000000     21613.000000
# mean   4.580302e+09  1.551734e-16        3.370842         2.114804
# std    2.876566e+09  1.000023e+00        0.930062         0.770085
# min    1.000102e+06 -1.746316e+00        0.000000         0.000000
# 25%    2.123049e+09 -7.584082e-01        3.000000         1.750000
# 50%    3.904930e+09 -2.464562e-01        3.000000         2.250000
# 75%    7.308900e+09  5.334707e-01        4.000000         2.500000
# max    9.900000e+09  2.471289e+00       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         2.161300e+04        2.161300e+04  21613.000000   21613.000000
# mean         -8.679188e-17       -2.945664e-16      1.494309       7.623467
# std           1.000023e+00        1.000023e+00      0.539989       1.105439
# ...

# %%
data_minmax_scaled= data_encoded.copy()



min_max_scaler = MinMaxScaler()
data_minmax_scaled[numerical_columns]= min_max_scaler.fit_transform(data_minmax_scaled[numerical_columns])
data_minmax_scaled.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    0.139308               3
# 1  6414100192    14 December 2017    0.439071               3
# 2  5631500400    15 February 2016    0.099573               2
# 3  2487200875    14 December 2017    0.501660               4
# 4  1954400510    15 February 2016    0.412518               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00             0.225888            0.274736           1.0
# 1             2.25             0.578680            0.359995           2.0
# 2             1.00             0.121827            0.507698           1.0
# 3             3.00             0.423858            0.239925           1.0
# 4             2.00             0.352792            0.404873           1.0
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  Zipcode  \
# ...

# %%
data_minmax_scaled.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  21613.000000    21613.000000     21613.000000
# mean   4.580302e+09      0.414054        3.370842         2.114804
# std    2.876566e+09      0.237107        0.930062         0.770085
# min    1.000102e+06      0.000000        0.000000         0.000000
# 25%    2.123049e+09      0.234234        3.000000         1.750000
# 50%    3.904930e+09      0.355619        3.000000         2.250000
# 75%    7.308900e+09      0.540541        4.000000         2.500000
# max    9.900000e+09      1.000000       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21613.000000        21613.000000  21613.000000   21613.000000
# mean              0.448729            0.438683      1.494309       7.623467
# std               0.212904            0.270681      0.539989       1.105439
# ...

# %%
corr_columns = ['Sale Price','Flat Area (in Sqft)','Lot Area (in Sqft)','Area of the House from Basement (in Sqft)','Basement Area (in Sqft)','Living Area after Renovation (in Sqft)','Lot Area after Renovation (in Sqft)']
orginal_date_corr = data_encoded[corr_columns].corr()
orginal_date_corr
# Out:
#                                            Sale Price  Flat Area (in Sqft)  \
# Sale Price                                   1.000000             0.701008
# Flat Area (in Sqft)                          0.701008             1.000000
# Lot Area (in Sqft)                           0.172150             0.347850
# Area of the House from Basement (in Sqft)    0.602328             0.868486
# Basement Area (in Sqft)                      0.294161             0.399662
# Living Area after Renovation (in Sqft)       0.626350             0.763638
# Lot Area after Renovation (in Sqft)          0.092319             0.170921
#
#                                            Lot Area (in Sqft)  \
# Sale Price                                           0.172150
# Flat Area (in Sqft)                                  0.347850
# Lot Area (in Sqft)                                   1.000000
# Area of the House from Basement (in Sqft)            0.320195
# ...

# %%
sns.heatmap(orginal_date_corr,annot=True)
# Out:
# <Axes: >
